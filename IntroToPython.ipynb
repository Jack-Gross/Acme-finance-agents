# %% [markdown]
# <a href="https://colab.research.google.com/github/Jack-Gross/Acme-finance-agents/blob/main/IntroToPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BUS 392: Getting Started with JupyterLab and Python

# %%
3+4
# Out:
# 7

# %%
print(3+4)
print(4+5)
# Out:
# 7
# 9

# %%
# The following statements will configure JupyterLab to display all output from a given code cell,
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
3+4
5+7
# Out:
# 12

# %%
x = 3
y = 4
z = x + y
print(z)
# Out:
# 7

# %%
yourName = input("What is your name?")
print("Hello " + yourName + "!")
# Out:
# What is your name? Kevin
# Hello Kevin!

# %%
example = [4, 0, 6, 1, -3, -1] # Creating a list of data
print(example) # Displaying the data
# Out:
# [4, 0, 6, 1, -3, -1]

# %%
sum(example)
# Out:
# 7

# %%
len(example)
# Out:
# 6

# %%
sum(example) / len(example)
# Out:
# 1.1666666666666667

# %%
import statistics
statistics.mean(example)
# Out:
# 1.1666666666666667

# %%
statistics.stdev(example)
# Out:
# 3.3115957885386114

# %%
statistics.pstdev(example)
# Out:
# 3.0230595245361758

# %%
import numpy as np
np.mean(example)
# Out:
# 1.1666666666666667

# %%
np.std(example)
# Out:
# 3.0230595245361753

# %%
np.std(example, ddof  = 1)
# Out:
# 3.311595788538611
